# %%
import pandas as pd
import numpy as np
import json
from pathlib import Path

# %%
# list dei paesi
countries = ["CA", "DE", "FR", "GB", "IN", "JP", "KR", "MX", "RU", "US"]

# cartella data contiene tutti i file json e csv ed è nella stessa dir del notebook
DATA_DIR = Path("data")

#creiamo i dizionari dove le Chiavi saranno gli acronimi dei paesi 
#e i loro contenuti saranno i dataframe corrispondenti
csv_dfs = {}
json_data = {}

#ciclo for per leggere tutti i file in automatico (invece di farli tutti a mano dato che hanno lo stesso nome)
for country in countries: #per ogni paese della lista creiamo il percorso del file
    csv_path = DATA_DIR / f"{country}videos.csv" 
    json_path = DATA_DIR / f"{country}_category_id.json"
    
    # Lettura dei CSV 
    df = pd.read_csv(csv_path, encoding="latin1", encoding_errors="replace") 
    #latin1 evita errori di lettura. i file youtube non sono utf-8
    #encoding_errors="replace" sostituisce un carattere anomalo con un altro sismbolo speciale
    #per evitare che crashi
    csv_dfs[country] = df #dizionario con chiave = country, valore = dataframe
    
    # Lettura JSON
    with open(json_path, encoding="utf-8") as f: #open apre il file json
        j = json.load(f) #lo trasforma in un dizionario python
    json_data[country] = j

print("Import completato")
# Out:
# Import completato

# %%
#verifica che ci siano tutti i paesi
csv_dfs.keys(), json_data.keys()
# Out:
# (dict_keys(['CA', 'DE', 'FR', 'GB', 'IN', 'JP', 'KR', 'MX', 'RU', 'US']),
#  dict_keys(['CA', 'DE', 'FR', 'GB', 'IN', 'JP', 'KR', 'MX', 'RU', 'US']))

# %%
csv_dfs["CA"].head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0        Eminem - Walk On Water (Audio) ft. BeyoncÃ©    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828   132239
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634130
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1      1688          13030  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4     21082          85067  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description
# 0  Eminem's new track Walk on Water ft. BeyoncÃ© ...
# 1  STill got a lot of packages. Probably will las...
# 2  WATCH MY PREVIOUS VIDEO â¶ \n\nSUBSCRIBE âº ...
# 3  I know it's been a while since we did this sho...
# 4  ð§: https://ad.gt/yt-perfect\nð°: https://...

# %%
# 1. Create a single dataframe with the concatenation of all input csv files,
#adding a column called country

#Per procedere con il primo punto, verifichiamo i seguenti punti:

# %%
#innanzitutto verifichiamo il numero di righe per ogni paese
for country, df in csv_dfs.items():
    print(country, len(df))
# Out:
# CA 40881
# DE 40840
# FR 40724
# GB 38916
# IN 37352
# JP 20523
# KR 34567
# MX 40451
# RU 40739
# US 40949

# %%
# verifichiamo che i nomi delle colonne non siano diversi tra csv.
for country, df in csv_dfs.items():
    print(country, " ", sorted(df.columns))

#sembrano tutti uguali e che non ci siano errori, vediamo se ci saranno problemi dopo
# Out:
# CA   ['category_id', 'channel_title', 'comment_count', 'comments_disabled', 'description', 'dislikes', 'likes', 'publish_time', 'ratings_disabled', 'tags', 'thumbnail_link', 'title', 'trending_date', 'video_error_or_removed', 'video_id', 'views']
# DE   ['category_id', 'channel_title', 'comment_count', 'comments_disabled', 'description', 'dislikes', 'likes', 'publish_time', 'ratings_disabled', 'tags', 'thumbnail_link', 'title', 'trending_date', 'video_error_or_removed', 'video_id', 'views']
# FR   ['category_id', 'channel_title', 'comment_count', 'comments_disabled', 'description', 'dislikes', 'likes', 'publish_time', 'ratings_disabled', 'tags', 'thumbnail_link', 'title', 'trending_date', 'video_error_or_removed', 'video_id', 'views']
# GB   ['category_id', 'channel_title', 'comment_count', 'comments_disabled', 'description', 'dislikes', 'likes', 'publish_time', 'ratings_disabled', 'tags', 'thumbnail_link', 'title', 'trending_date', 'video_error_or_removed', 'video_id', 'views']
# IN   ['category_id', 'channel_title', 'comment_count', 'comments_disabled', 'description', 'dislikes', 'likes', 'publish_time', 'ratings_disabled', 'tags', 'thumbnail_link', 'title', 'trending_date', 'video_error_or_removed', 'video_id', 'views']
# JP   ['category_id', 'channel_title', 'comment_count', 'comments_disabled', 'description', 'dislikes', 'likes', 'publish_time', 'ratings_disabled', 'tags', 'thumbnail_link', 'title', 'trending_date', 'video_error_or_removed', 'video_id', 'views']
# KR   ['category_id', 'channel_title', 'comment_count', 'comments_disabled', 'description', 'dislikes', 'likes', 'publish_time', 'ratings_disabled', 'tags', 'thumbnail_link', 'title', 'trending_date', 'video_error_or_removed', 'video_id', 'views']
# MX   ['category_id', 'channel_title', 'comment_count', 'comments_disabled', 'description', 'dislikes', 'likes', 'publish_time', 'ratings_disabled', 'tags', 'thumbnail_link', 'title', 'trending_date', 'video_error_or_removed', 'video_id', 'views']
# RU   ['category_id', 'channel_title', 'comment_count', 'comments_disabled', 'description', 'dislikes', 'likes', 'publish_time', 'ratings_disabled', 'tags', 'thumbnail_link', 'title', 'trending_date', 'video_error_or_removed', 'video_id', 'views']
# US   ['category_id', 'channel_title', 'comment_count', 'comments_disabled', 'description', 'dislikes', 'likes', 'publish_time', 'ratings_disabled', 'tags', 'thumbnail_link', 'title', 'trending_date', 'video_error_or_removed', 'video_id', 'views']

# %%
#ora creiamo il nuovo data frame:

# Creiamo una lista vuota che useremo per salvare i vari dataframe
dfs_wc = []

# Per ogni paese (country) e per ogni dataframe associato...
for country, df in csv_dfs.items():
    
    # 1. Facciamo una copia del dataframe originale
    #    (così evitiamo di modificare accidentalmente quello salvato nel dizionario)
    temp = df.copy()
    
    # 2. Aggiungiamo una colonna nuova chiamata "country"
    #    e come valore mettiamo il nome del paese (es: "CA", "JP", "US", ecc.)
    temp["country"] = country
    
    # 3. Mettiamo questo dataframe modificato dentro la lista
    dfs_wc.append(temp)

# 4. Uniamo tutti i dataframe della lista in un unico grande dataframe
df2 = pd.concat(dfs_wc, ignore_index=True) #ignore_index

# 5. Mostriamo qualche informazione
print("Concatenazione completata. Shape:", df2.shape)
df2.head()  #check
# Out:
# Concatenazione completata. Shape: (375942, 17)
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0        Eminem - Walk On Water (Audio) ft. BeyoncÃ©    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828   132239
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634130
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1      1688          13030  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4     21082          85067  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description country
# 0  Eminem's new track Walk on Water ft. BeyoncÃ© ...      CA
# 1  STill got a lot of packages. Probably will las...      CA
# 2  WATCH MY PREVIOUS VIDEO â¶ \n\nSUBSCRIBE âº ...      CA
# 3  I know it's been a while since we did this sho...      CA
# 4  ð§: https://ad.gt/yt-perfect\nð°: https://...      CA

# %%
#2. Extract all videos that have no tag.

# %%
#vediamo alcune informazioni sulla variabile tags:

df2["tags"].apply(type).unique()
# Out:
# array([<class 'str'>], dtype=object)

# %%
df2["tags"].head(10)
# Out:
# 0    Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...
# 1    plush|"bad unboxing"|"unboxing"|"fan mail"|"id...
# 2    racist superman|"rudy"|"mancuso"|"king"|"bach"...
# 3    ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...
# 4    edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...
# 5    #DramaAlert|"Drama"|"Alert"|"DramaAlert"|"keem...
# 6    Funny Moments|"Montage video games"|"gaming"|"...
# 7                                      SHANtell martin
# 8    logan paul vlog|"logan paul"|"logan"|"paul"|"o...
# 9                 God|"Sheldon Cooper"|"Young Sheldon"
# Name: tags, dtype: object

# %%
#tags contieneuna stringa con i tag separati da |

#troviamo i video senz tag cercando quelli che hanno una stringa vuota
# oppure che hanno NaN:

df2[df2["tags"].isna() | (df2["tags"] == "")]

#non restituisce niente, significa che i video senza tags non sono salvati
#ne come stringhe vuote ne come NaN.
# Out:
# Empty DataFrame
# Columns: [video_id, trending_date, title, channel_title, category_id, publish_time, tags, views, likes, dislikes, comment_count, thumbnail_link, comments_disabled, ratings_disabled, video_error_or_removed, description, country]
# Index: []

# %%
#proiamo a identificare dei valori di tags che potrebbero indicare l'assenza
#di tags, rintracciando quelli che non hanno |:
# Mostra i valori sospetti (0 separatori "|")
df2[df2["tags"].apply(lambda x: str(x).count("|") == 0)]

#sembra che l'assenza di tags sia identificata dal valore "[none]". 
#attenta che anche i video con un solo tag (non hanno pipe) 
# e i video che sono stati codificati da lingue con alfabeto diverso 
# (sempre senza pipe)appaiono in questo risultato:
#rintracciamo i [none].
# Out:
#            video_id trending_date  \
# 7       2kyS6SvSYSE      17.14.11
# 41      JwboxqDylgg      17.14.11
# 58      9B-q8h31Bpk      17.14.11
# 78      1UE5Dq1rvUA      17.14.11
# 86      pmJQ4KwliX4      17.14.11
# ...             ...           ...
# 375815  VGykknw9eCM      18.14.06
# 375819  fAIX12F6958      18.14.06
# 375865  gS1DbvHHVH0      18.14.06
# 375873  E4c7EE8_IX0      18.14.06
# 375938  1h7KV2sjUWY      18.14.06
#
#                                                     title       channel_title  \
# 7                      WE WANT TO TALK ABOUT OUR MARRIAGE        CaseyNeistat
# 41      Canada Soccer's Women's National Team v USA In...       Canada Soccer
# 58      John Oliver Tackles Louis C.K. And Donald Trum...            TV Shows
# 78                Taylor Swift Perform Ready For It - SNL          Ken Reactz
# 86      LATEST Q POSTS: ROTHSCHILDS, HOUSE OF SAUD, lL...        James Munder
# ...                                                   ...                 ...
# 375815  Made Defiant: The Mixtape ft. Neymar Jr., Kane...        Beats by Dre
# 375819  Bumblebee (2018) - Official Teaser Trailer - P...  Paramount Pictures
# 375865                          Going in to brain surgery       Simone Giertz
# 375873                                    Weezer - Africa              weezer
# 375938                         True Facts : Ant Mutualism            zefrank1
#
#         category_id              publish_time             tags     views  \
# 7                22  2017-11-13T17:13:01.000Z  SHANtell martin    748374
# 41               17  2017-11-13T05:53:49.000Z           [none]     36311
# 58               22  2017-11-13T04:49:26.000Z           [none]    106029
# 78               24  2017-11-12T05:18:02.000Z           [none]    320964
# 86                2  2017-11-12T21:25:40.000Z           [none]    116820
# ...             ...                       ...              ...       ...
# 375815           10  2018-06-07T07:01:06.000Z           [none]   3577614
# 375819            1  2018-06-05T07:00:01.000Z           [none]  19864779
# 375865           28  2018-05-30T14:22:13.000Z           [none]   1635301
# 375873           10  2018-05-29T12:00:11.000Z           [none]   4682557
# 375938           22  2018-05-18T01:00:06.000Z           [none]   1064798
#
#          likes  dislikes  comment_count  \
# 7        57534      2967          15959
# 41         277        28             13
# 58        1270       101            181
# 78        8069       285            717
# 86        1503       139           1066
# ...        ...       ...            ...
# 375815   12318      1345           1414
# 375819  228670     16420          46318
# 375865  120791      1098          20711
# 375873  115240      5069           9170
# 375938   60008       382           3936
#
#                                         thumbnail_link  comments_disabled  \
# 7       https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg              False
# 41      https://i.ytimg.com/vi/JwboxqDylgg/default.jpg              False
# 58      https://i.ytimg.com/vi/9B-q8h31Bpk/default.jpg              False
# 78      https://i.ytimg.com/vi/1UE5Dq1rvUA/default.jpg              False
# 86      https://i.ytimg.com/vi/pmJQ4KwliX4/default.jpg              False
# ...                                                ...                ...
# 375815  https://i.ytimg.com/vi/VGykknw9eCM/default.jpg              False
# 375819  https://i.ytimg.com/vi/fAIX12F6958/default.jpg              False
# 375865  https://i.ytimg.com/vi/gS1DbvHHVH0/default.jpg              False
# 375873  https://i.ytimg.com/vi/E4c7EE8_IX0/default.jpg              False
# 375938  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg              False
#
#         ratings_disabled  video_error_or_removed  \
# 7                  False                   False
# 41                 False                   False
# 58                 False                   False
# 78                 False                   False
# 86                 False                   False
# ...                  ...                     ...
# 375815             False                   False
# 375819             False                   False
# 375865             False                   False
# 375873             False                   False
# 375938             False                   False
#
#                                               description country
# 7       SHANTELL'S CHANNEL - https://www.youtube.com/s...      CA
# 41      Canada Soccer's Women's National Team face riv...      CA
# 58                      John Oliver on News, Politics ...      CA
# 78      Thanks for watching please subscribe and subsc...      CA
# 86      https://pastebin.ca/3930472\n\nSupport My Chan...      CA
# ...                                                   ...     ...
# 375815  When your time comes, you have two choices. Yo...      US
# 375819  Every adventure has a beginning. Watch the off...      US
# 375865  Weâll post an update on Instagram and Twitte...      US
# 375873  Stream + download the song: http://fanlink.to/...      US
# 375938                                                NaN      US
#
# [44532 rows x 17 columns]

# %%
no_tags = df2[df2["tags"].str.strip().str.lower() == "[none]"]

# %%
len(no_tags)
# Out:
# 37698

# %%
no_tags.head()
# Out:
#        video_id trending_date  \
# 41  JwboxqDylgg      17.14.11
# 58  9B-q8h31Bpk      17.14.11
# 78  1UE5Dq1rvUA      17.14.11
# 86  pmJQ4KwliX4      17.14.11
# 98  lHcXhBojpeQ      17.14.11
#
#                                                 title    channel_title  \
# 41  Canada Soccer's Women's National Team v USA In...    Canada Soccer
# 58  John Oliver Tackles Louis C.K. And Donald Trum...         TV Shows
# 78            Taylor Swift Perform Ready For It - SNL       Ken Reactz
# 86  LATEST Q POSTS: ROTHSCHILDS, HOUSE OF SAUD, lL...     James Munder
# 98  ä¸å±TVBè¦å¸ï¼ææ£10å¹´éæ¢
# ç«¹é¦¬é«®å¦...  ææç¾æç
#
#     category_id              publish_time    tags   views  likes  dislikes  \
# 41           17  2017-11-13T05:53:49.000Z  [none]   36311    277        28
# 58           22  2017-11-13T04:49:26.000Z  [none]  106029   1270       101
# 78           24  2017-11-12T05:18:02.000Z  [none]  320964   8069       285
# 86            2  2017-11-12T21:25:40.000Z  [none]  116820   1503       139
# 98           22  2017-11-12T12:49:50.000Z  [none]   88061     47        58
#
#     comment_count                                  thumbnail_link  \
# 41             13  https://i.ytimg.com/vi/JwboxqDylgg/default.jpg
# 58            181  https://i.ytimg.com/vi/9B-q8h31Bpk/default.jpg
# 78            717  https://i.ytimg.com/vi/1UE5Dq1rvUA/default.jpg
# 86           1066  https://i.ytimg.com/vi/pmJQ4KwliX4/default.jpg
# 98             17  https://i.ytimg.com/vi/lHcXhBojpeQ/default.jpg
#
#     comments_disabled  ratings_disabled  video_error_or_removed  \
# 41              False             False                   False
# 58              False             False                   False
# 78              False             False                   False
# 86              False             False                   False
# 98              False             False                   False
#
#                                           description country
# 41  Canada Soccer's Women's National Team face riv...      CA
# 58                  John Oliver on News, Politics ...      CA
# 78  Thanks for watching please subscribe and subsc...      CA
# 86  https://pastebin.ca/3930472\n\nSupport My Chan...      CA
# 98                                                NaN      CA

# %%
#3. For each channel, determine the total number of views

# %%
df2.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0        Eminem - Walk On Water (Audio) ft. BeyoncÃ©    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828   132239
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634130
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1      1688          13030  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4     21082          85067  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description country
# 0  Eminem's new track Walk on Water ft. BeyoncÃ© ...      CA
# 1  STill got a lot of packages. Probably will las...      CA
# 2  WATCH MY PREVIOUS VIDEO â¶ \n\nSUBSCRIBE âº ...      CA
# 3  I know it's been a while since we did this sho...      CA
# 4  ð§: https://ad.gt/yt-perfect\nð°: https://...      CA

# %%
df2['views'].dtype
#non abbiamo problemi con i volori di views. possiamo eseguire operazione somma
# Out:
# dtype('int64')

# %%
df2.groupby('channel_title')['views'].sum().sort_values(ascending=False)
# Out:
# channel_title
# ChildishGambinoVEVO     11016766510
# Marvel Entertainment    10430605449
# NickyJamTV               9479859505
# Ozuna                    8623329509
# ibighit                  8205572221
#                            ...
# NavylittleMonster               365
# Videostendencias                302
# No Comment TV                   284
# Sport Life                      163
# Alexander Redking               153
# Name: views, Length: 37824, dtype: int64

# %%
#4. Save all rows with disabled comments and disabled ratings,
#  or that have video_error_or_removed in a new dataframe called
#  excluded, and remove those rows from the original dataframe.

# %%
print(df2['comments_disabled'].dtype)
print(df2['ratings_disabled'].dtype)
print(df2['video_error_or_removed'].dtype)

#sono tutt e e tre booleane, possiamo laorarci sopra senza problemi
# Out:
# bool
# bool
# bool

# %%
# Seleziona le righe dove:
# - commenti disabilitati e rating disabilitati
#   OPPURE
# - video in errore o rimosso
excluded = df2[
    ((df2['comments_disabled'] == True) & (df2['ratings_disabled'] == True)) |
    (df2['video_error_or_removed'] == True)
]

# Rimuovi queste righe dal dataframe originale con drop
df2 = df2.drop(excluded.index)

#(ora df2 ha i buchi negli indici)

# %%
len(excluded)
#sono stati esclusi 2620 video
# Out:
# 2620

# %%
#5. Add a like_ratio column storing the ratio between the 
# number of likes and of dislikes

#controlliamo prima se ci sono video con 0 dislike
#per evitare eventualmente di fare una divisione per 0
df2[df2['dislikes'] == 0]

#essendo che ce ne sono, dobbiamo considerare che il like_ratio
#restituirà NaN quando il video ha sia 0 like che zero dislike, 
#e sostituirà inf quando avrà un numero positivo di like e zero dislike.
# Out:
#            video_id trending_date  \
# 67      amEZKmJQ4Io      17.14.11
# 161     bsgocWaULIU      17.14.11
# 235     wDEA3rpYHnI      17.15.11
# 271     LfajgipdxmA      17.15.11
# 313     8sdQ7dP9Drs      17.15.11
# ...             ...           ...
# 358439  8WbxbqwdWog      18.13.03
# 360544  zkrq7Kpd1so      18.24.03
# 363543  9TUBf6l7FBg      18.14.04
# 363744  9TUBf6l7FBg      18.15.04
# 363948  9TUBf6l7FBg      18.16.04
#
#                                                     title  \
# 67                Drako - Watch Me Do It [Official Video]
# 161                            Troydon bent - Jam African
# 235     Marie-Louise Arsenault rÃ©plique Ã  Denise Bom...
# 271                    How does Yoonla work? Learning CPA
# 313     Today's News: It's On - Get The Goods, Novembe...
# ...                                                   ...
# 358439  Camera Goes on Japanese Sushi Conveyor Belt Sh...
# 360544  ULTRA LIVE presents Ultra Music Festival 2018 ...
# 363543                      Coachella 2018 LIVE Channel 1
# 363744                      Coachella 2018 LIVE Channel 1
# 363948                      Coachella 2018 LIVE Channel 1
#
#                             channel_title  category_id  \
# 67                      babygranderecords           10
# 161                          Troydon bent           10
# 235                           TV Classics           22
# 271     Anthonys Digital Lifestyle Dotcom           22
# 313                    Whistler Blackcomb           17
# ...                                   ...          ...
# 358439                            TkyoSam           22
# 360544                             UMF TV           10
# 363543                          Coachella           10
# 363744                          Coachella           10
# 363948                          Coachella           10
#
#                     publish_time  \
# 67      2017-10-23T19:38:36.000Z
# 161     2016-12-08T19:29:25.000Z
# 235     2017-11-13T01:26:37.000Z
# 271     2017-11-14T10:57:38.000Z
# 313     2017-11-14T18:18:21.000Z
# ...                          ...
# 358439  2018-03-06T16:18:30.000Z
# 360544  2018-03-24T07:55:21.000Z
# 363543  2018-04-05T06:48:28.000Z
# 363744  2018-04-05T06:48:28.000Z
# 363948  2018-04-05T06:48:28.000Z
#
#                                                      tags     views  likes  \
# 67      Drako|"Watch Me Do It"|"watch me"|"migos"|"dap...     25887      0
# 161     New Danchall music world reggae traditional so...     16921    187
# 235     Marie-Louise Arsenault qui rÃ©plique Ã  Denise...     15800     88
# 271     How does Yoonla work|"free work from home"|"le...     11810      1
# 313                                                [none]      4851     31
# ...                                                   ...       ...    ...
# 358439  æ±äº¬ãµã |"jvlog"|"jvlogger"|"tkyosam"|"tok...    639517      0
# 360544  ultra music festival|"umf"|"mix"|"relive"|"aft...   1648886      0
# 363543                                             [none]   3598220      0
# 363744                                             [none]  11137071      0
# 363948                                             [none]  24004779      0
#
#         dislikes  comment_count  \
# 67             0              6
# 161            0              5
# 235            0              0
# 271            0              0
# 313            0              0
# ...          ...            ...
# 358439         0           1059
# 360544         0            548
# 363543         0              0
# 363744         0              2
# 363948         0              3
#
#                                            thumbnail_link  comments_disabled  \
# 67         https://i.ytimg.com/vi/amEZKmJQ4Io/default.jpg              False
# 161        https://i.ytimg.com/vi/bsgocWaULIU/default.jpg              False
# 235        https://i.ytimg.com/vi/wDEA3rpYHnI/default.jpg               True
# 271        https://i.ytimg.com/vi/LfajgipdxmA/default.jpg              False
# 313        https://i.ytimg.com/vi/8sdQ7dP9Drs/default.jpg              False
# ...                                                   ...                ...
# 358439     https://i.ytimg.com/vi/8WbxbqwdWog/default.jpg              False
# 360544     https://i.ytimg.com/vi/zkrq7Kpd1so/default.jpg              False
# 363543  https://i.ytimg.com/vi/9TUBf6l7FBg/default_liv...              False
# 363744  https://i.ytimg.com/vi/9TUBf6l7FBg/default_liv...              False
# 363948  https://i.ytimg.com/vi/9TUBf6l7FBg/default_liv...              False
#
#         ratings_disabled  video_error_or_removed  \
# 67                  True                   False
# 161                False                   False
# 235                False                   False
# 271                False                   False
# 313                False                   False
# ...                  ...                     ...
# 358439              True                   False
# 360544              True                   False
# 363543              True                   False
# 363744              True                   False
# 363948              True                   False
#
#                                               description country  like_ratio
# 67      PURCHASE / STREAM WATCH ME DO IT https://fanli...      CA         NaN
# 161     Troydon bent performing Jam African produced b...      CA         inf
# 235     Moment favori Ã  la tÃ©lÃ© quÃ©bÃ©coise: Marie...      CA         inf
# 271     How does Yoonla work? Learning CPA marketing t...      CA         inf
# 313     Todayâs news: itâs on. Whistler Mountain w...      CA         inf
# ...                                                   ...     ...         ...
# 358439  I will call this video A Camera's Journey Thro...      US         NaN
# 360544  Tune in here for the Ultra Music Festival 2018...      US         NaN
# 363543  For more cameras and VR180 immersive experienc...      US         NaN
# 363744  For more cameras and VR180 immersive experienc...      US         NaN
# 363948  For more cameras and VR180 immersive experienc...      US         NaN
#
# [7387 rows x 18 columns]

# %%
df2['like_ratio'] = df2['likes'] / df2['dislikes']
df2.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0        Eminem - Walk On Water (Audio) ft. BeyoncÃ©    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828   132239
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634130
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1      1688          13030  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4     21082          85067  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description country  like_ratio
# 0  Eminem's new track Walk on Water ft. BeyoncÃ© ...      CA   18.135076
# 1  STill got a lot of packages. Probably will las...      CA   75.707346
# 2  WATCH MY PREVIOUS VIDEO â¶ \n\nSUBSCRIBE âº ...      CA   27.352500
# 3  I know it's been a while since we did this sho...      CA   66.485168
# 4  ð§: https://ad.gt/yt-perfect\nð°: https://...      CA   77.513044

# %%
# 6. Cluster the publish time into 10-minute intervals
# # (e.g. from 02:20 to 02:30)

#facciamo un po di verifiche preliminari:

# %%
df2['publish_time'].dtype
#la colonna è trattata come stringa (object)
# Out:
# dtype('O')

# %%
df2['publish_time'].head()
# Out:
# 0    2017-11-10T17:00:03.000Z
# 1    2017-11-13T17:00:00.000Z
# 2    2017-11-12T19:05:24.000Z
# 3    2017-11-12T18:01:41.000Z
# 4    2017-11-09T11:04:14.000Z
# Name: publish_time, dtype: object

# %%
df2['publish_time'].isna().sum() #nessun valore mancante
# Out:
# 0

# %%
df2['publish_time_dt'] = pd.to_datetime(df2['publish_time'], errors='coerce')

# errors = 'coerece' Se un valore non può essere convertito in data-ora, trasformalo in NaT (Not a Time) invece di dare errore. 
# creiamo una nuova colonna con il tempo di pubblicazione 
#convertito in formato datetime.

df2[['publish_time_dt']].head()
# Out:
#             publish_time_dt
# 0 2017-11-10 17:00:03+00:00
# 1 2017-11-13 17:00:00+00:00
# 2 2017-11-12 19:05:24+00:00
# 3 2017-11-12 18:01:41+00:00
# 4 2017-11-09 11:04:14+00:00

# %%
# stabiliamo l'Inizio e fine dell’intervallo da 10 minuti
start = df2['publish_time_dt'].dt.floor('10T') 
##prende ogni orario di pubblicazione e lo arrotonda verso
# il basso al blocco di 10 minuti più vicino.
#10T = 10 minuti
#floor arrotonda verso il basso temporalmente al multiplo di 10 piu vicino
end = start + pd.Timedelta(minutes=10)
#aggiunge 10 minuti al valore di start per ottenere la fine dell’intervallo.
#pd.Timedelta(minutes=10) crea un oggetto “durata temporale”
#  di 10 minuti.  Sommarlo allo start crea una variabile
#  che rappresenta l’estremo superiore dell’intervallo.


#  Etichettiamo l'intervallo, solo con ore e minuti
df2['publish_time_interval'] = start.dt.strftime('%H:%M') + ' - ' + end.dt.strftime('%H:%M')

# %%
#7. For each interval, determine the number of videos,
#  average number of likes and of dislikes.

# %%
interval_stats = df2.groupby('publish_time_interval').agg(
    num_videos=('publish_time_dt', 'count'),
    avg_likes=('likes', 'mean'),
    avg_dislikes=('dislikes', 'mean')
).reset_index()

#prima raggruppiamo per publish_time_interval
#successivamente con .agg applichiamo le funzioni count e mean
#alle colonne publish_time_dt, likes e dislike
interval_stats.head()
# Out:
#   publish_time_interval  num_videos     avg_likes  avg_dislikes
# 0         00:00 - 00:10        2897  61288.115637   3808.149465
# 1         00:10 - 00:20        1509  22748.138502   1449.836315
# 2         00:20 - 00:30        1241  21378.280419   1072.344883
# 3         00:30 - 00:40        1614  36853.560719    955.890954
# 4         00:40 - 00:50        1269  42198.623325   1909.301812
